# %% [markdown]
# <a href="https://colab.research.google.com/github/Timmy0204/tin-chen/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  age = int(input("please Enter your age:"))
  print(f"Your age is:{age}")
except ValueError:
  print("請輸入正確格式")
# Out:
# please Enter your age:nkjl15
# 請輸入正確格式

# %%
s = input()
print(f"hello, {s}")
# Out:
# taiwan
# hello,taiwan

# %%
x , y = map(int, input().split())
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x ** y)
print(x % y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1216/1843897089.py in <cell line: 0>()
# ----> 1 x , y = map(int, input().split())
#       2 print(x + y)
#       3 print(x - y)
#       4 print(x * y)
#       5 print(x / y)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
x = int(input("x: "))
y = int(input("y: "))

t = x
x = y
y = t

print(f"x: {x}, y: {y}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1216/3943737256.py in <cell line: 0>()
# ----> 1 x = int(input("x: "))
#       2 y = int(input("y: "))
#       3
#       4 t = x
#       5 x = y
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
a = int(input())
b, c = map(int, input().split())
s = input()
print(f"{a+b+c} {s}")

# %%
num = int(input())
print(f"百位數字: {num // 100}")
print(f"十位數字: {num // 10 % 10}")
print(f"個位數字: {num % 10}")

# %%
x = int(input())
# n，1 ≤ n ≤ 200
n = 42

# %%
n = int(input())
print(n % 12*5+n // 12 * 50)

# %%
num = int(input())
if num > 200:
  print(f"{num} > 200")
else:
  print(f"{num} < 200")

print("程式結束")

# %%
a, b, c = map(int,input().split())
if a > b and a > c:
  print(f"最大值: {a}")
elif b >= a and b >= c:
  print(f"最大值: {b}")
elif c >= a and c >= b:
  print(f"最大值: {c}")

# %%
a, b, c map(int, input().split())
ans = None

if a >= b:
  ans = a
else:
  ans = b
if c > ans:
  ans = c
if d > ans:
  ans = d
print(f"最大值: {ans}")

# %%
M, D = map(int, input().split())
s = (M*2 + D) % 3
if s == 0:
  print("普通")
elif s == 1:
  print("吉")
elif s == 2:
  print("大吉")

# %%
T, G, W, E, B = map(int, input().split())
if T >= G+W+E+B:
  print(G+W+E+B)
else:
  print(-1)

# %%
from IPython.core.completer import back_latex_name_matches
A, B, C, D = map(int, input().split())
l = A+B
r = C+D
if l > r:
  print("Left")
elif l == r:
  print("Balanced")
elif l < r:
  print("Right")

# %%
i = 0
while i < 600:
  print(i)
  i += 1
print("end")

# %%
n = int(input())
i = 1
while i <= n:
  if i != n:
    print(i,end="+")
  elif i == n:
    print(i,end="=")
    sum = sum + i
  i += 1
print(sum)

# %%
m = int(input())
for i in range(1, n+1, 1):
  print(i, end="")

# %%
m = int(input())
for i in range(1, n+1, 1):
  print(i, end="")

# %%
n = int(input())
for i in range(8, )

# %%
n = int(input())
if n <= 10:
  print (n*6)
elif n > 10 and n <= 20:
  print ((n-10)*2+60)
elif n > 20 and n <= 40:
  print((n-20)*1+80)
elif n >= 40:
  print(100)

# %%
n = int (input())
a = 0
b = 0
c = 0

for i in range():
  x = int(input())
  if x % 3 == 0:
    a += 1
  elif x% 3 == 1:
    b += 1
  elif x % ==2:
    c += 1
print(f"{a} {b} {c}")

# %%
num = [10, 20, 30, 40, 50]
print(num)
print(num[0])
print(num[1])
print(num[2])
print(num[3])
print(num[4])
print(num[-1])
print(num[-2])
print(num[-3])
print(num[-4])
print(num[-5])
print(f"串列長度: {len(num)}")
# Out:
# [10, 20, 30, 40, 50]
# 10

# %%
print(num[1:4])
print(num[:3])
print(num[2:])
print(num[:])
print(num[0:5:2])
print(num[-3:])
print(num[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 30, 50]
# [30, 40, 50]

# %%
num = [3, 4, 5]
num.append(6)
print(num)
print(num)


num = [3, 4, 5]
num.insert(1, 70)
print(num)


num = [3, 4, 5, 4]
num.remove(4)
print(num)

num = [3, 4, 5]
num.pop()
print(num)
# Out:
# [3, 4, 5, 6]
# [3, 4, 5, 6]
# [3, 70, 4, 5]
# [3, 5, 4]
# [3, 4]

# %%
# clear
numbers = [3, 4, 5]
numbers.clear()
print(numbers)

# copy
numbers = [3, 4, 5]
x = numbers.copy()
x.append(6)
print(numbers)
print(x)

# count
numbers = [3, 4, 5, 4, 4]
print(numbers.count(4))

# index()
numbers = [3, 4, 5, 4]
print(numbers.index(4)) # 第一個 4 出現在 哪一個位置

# reverse
numbers = [3, 4, 5]
numbers.reverse()
print(numbers)

# sort 排序
numbers = [5, 3, 4, 2, -1, -6, 7, 10]
numbers.sort() # 由小到大
print(numbers)

numbers.sort(reverse = True)
print(numbers)
# Out:
# []
# [3, 4, 5]
# [3, 4, 5, 6]
# 3
# 1
# [5, 4, 3]
# [-6, -1, 2, 3, 4, 5, 7, 10]
# [10, 7, 5, 4, 3, 2, -1, -6]

# %%
num1 = [1, 2, 3, 4, 5]
num2 = num1

# %%
num1 = [1, 2, 3, 4, 5, 6]
num2 = num1
num1.append(6)

num3 = num1[:]
num4 = num1.copy()

num1.append(7)
num3.append(10)

print(f"num1: {{num1}\nnum2: {num2}\nnum3: {num3}\num4: {num4}}")

# %%
num = [3, 2, 7, 8, 1, 10, 15]
for i in range(len(num)):
  print(num[i], end="")

print()

for i in range(lrn(num)-1, -1, -1):
  print(num[i], end="")


for v in num:
  print(v, end="")


print()

for i, v in enumerate(num):
  print(f"{i}: {v}")
# Out:
# 3
# 2
# 7
# 8
# 1
# 10
# 15

# %%
n = int(input())
sum = 0
for i in range(n):
  a, b, c = map(int, input().split())
  sum = sum +a*100 + b*500 + c*1000
print(sum)

# %%
n = int(input)

# %%
l1 = list(map(int, input().split()))
print(l1)
# Out:
# 20 50
# [20, 50]

# %%
s = input()
ans = 0
for v in s:
  if v =="a"
    ans += 1
print(ans)

s ="fadaffgahtdar"
# Out:
#   File "/tmp/ipykernel_1582/1406324465.py", line 4
#     if v =="a"
#               ^
# SyntaxError: expected ':'

# %%
n = int(input())
sumA = 0
sumB = 0

for i in range(n):
  A, B, people = map(int, input().split())
  if A > B:
    sumA = sumA + people
  else:
    sumB = sumB + people

if sumA > sumB:
  print(f"1 {sumA}")
else:
  print(f"2 {sumB}")

# %%
n = int(input())
ele = list(map(int, input().split()))
floor = 1
ans = 0

for i in range(len(ele)):
  if ele[i] > floor:
    ans = ans + (ele[i] -floor)*3
  else:
    ans = ans + (floor - ele[i])*2

  floor = ele[i]

print(ans)

# %%
N = int(input())
li = list(map(int, input().split()))

mean = sum(li) // N

max_ = max(li)
min_ = min(li)

maxID = None
minID = None

for i in range(N):
  if li[i] == max_:
    maxID = i
  if li[i] == min_:
    minID = i

trans = max_ - mean

li[maxID] = li[maxID] - trans
li[minID] = li[minID] + trans

for v in li:
  print(v, edd=" ")

# %%
def getBmi(height, weight):
  height = height/100
  bmi = weight/(height*height)
  return bmi

def measure(bmi):
  if bmi < 18.5:
    return "體重過輕"
  elif 18.5 <= bmi < 24:
    return "體重正常"
  elif 24 <= bmi < 27:
    return "體重過重"
  elif 27 <= bmi < 30:
    return "輕度肥胖"

# %%
h = int(input("請輸入身高(cm): "))
w = int(input("請輸入體重(kg): "))
b = getBmi(h, w)
m = measure(b)
print(f"你的 bmi: {b}, 測量結果為: {m}")

# %%
def show():
  number = 3
  print(f"show. number: {number}")

show()
# print(number) 區域變數的生命週期在函式結束時, 就會把記憶體清空

# %%
n, D = map(int, input().split())
li = list(map(int, input().split()))
ans = 0
buy = li[0]
sell = 0
for i in range(1, n):
  price = li[i]
  if buy > 0:
    if price >= buy + D:
      ans += price - buy
      sell = price
      buy = 0
  else:
    if price <= sell - D:
      buy = price
      sell = 0
print(ans)

# %%
pos = 0
k = int(input())
x1, y1 = map(int, input().split())
x2, y2 = map(int, input().split())

while k > 0:
  pos += k
  if pos % x1 == 0:
    k -= y1
  if pos % x2 == 0:
    k -= y2

print(pos)

# %%
class Warrior:
  def __init__(self, name, gender, weapon = "bat"):
    self.level = 1
    self.exp = 0

    self.n = name
    self.g = gender
    self.w = weapon
    print(f"建立了戰士: {self.n}")
  def attack(self):
    print(f"{self.n} 用 {self.w} 攻擊")

# %%
w1 = Warrior(name="Lucas",gender = "Male")
w2 = Warrior(name="Allie",gender = "Female", weapon="sword")
print(f"w1 戰士姓名: {w1.n}, w1 戰士武器: {w1.w}")
print(f"w2 戰士姓名: {w2.n}, w2 戰士武器: {w2.w}")

w1.attack()
w2.attack()
# Out:
# 建立了戰士: Lucas
# 建立了戰士: Allie

# %%
print(f"w1 戰士姓名:")

# %%
"""
完成 Hero 類別的建構子
共同屬性 -> hp 設100, level 設 1
客製化屬性 -> name, job(職業), weapon(武器, 預設 = fist)
"""
class Hero:
  # TODO: 在這裡補上 5 個屬性
  # hp, level, name, job, weapon
  def __init__(self):
    pass

  # TODO: 完成 attack 方法
  # 要求: 印出 <名字> 用 <武器> 攻擊 xx 造成 30 點傷害 !
  def attack(self):
    pass

  # 要求把 hp 加 20，最多不能超過 100
  # 印出 <名字> 補血，現在 hp: <hp>
  def heal(self):
    pass

"""
創立兩個角色，並讓他們互相攻擊
1. 用名字建立兩個 Hero
2. 讓他們互相 attack 跟 heal
3. 印出他們的 hp
"""

# %%
import pandas as pd

# 準備一組 YouBike 站點的假資料 (字典 → DataFrame)
data = {
    "站名":   ["大安站", "信義站", "中山站", "松山站", "大安森林", "市府站", "南港站", "內湖站"],
    "行政區": ["大安區", "信義區", "中山區", "松山區", "大安區", "信義區", "南港區", "內湖區"],
    "可借":   [12, 0, 8, 5, 20, 3, 0, 15],
    "可還":   [8, 20, 12, 15, 0, 17, 25, 5],
    "總停車格": [20, 20, 20, 20, 20, 20, 25, 20],
}

df = pd.DataFrame(data)
df
# Out:
#      站名  行政區  可借  可還  總停車格
# 0   大安站  大安區  12   8    20
# 1   信義站  信義區   0  20    20
# 2   中山站  中山區   8  12    20
# 3   松山站  松山區   5  15    20
# 4  大安森林  大安區  20   0    20
# 5   市府站  信義區   3  17    20
# 6   南港站  南港區   0  25    25
# 7   內湖站  內湖區  15   5    20

# %%
# 看資料的常用指令
print("前 3 列：")
print(df.head())          # 看前幾列 (預設 5)

print("\n這張表有幾列幾欄:", df.shape)   # (列數, 欄數)

print("\n所有欄位名稱:", list(df.columns))

df.describe()
# Out:
# 前 3 列：
#      站名  行政區  可借  可還  總停車格
# 0   大安站  大安區  12   8    20
# 1   信義站  信義區   0  20    20
# 2   中山站  中山區   8  12    20
# 3   松山站  松山區   5  15    20
# 4  大安森林  大安區  20   0    20
#
# 這張表有幾列幾欄: (8, 5)
#
# 所有欄位名稱: ['站名', '行政區', '可借', '可還', '總停車格']
#               可借        可還       總停車格
# count   8.000000   8.00000   8.000000
# mean    7.875000  12.75000  20.625000
# std     7.278883   8.20714   1.767767
# min     0.000000   0.00000  20.000000
# 25%     2.250000   7.25000  20.000000
# 50%     6.500000  13.50000  20.000000
# 75%    12.750000  17.75000  20.000000
# max    20.000000  25.00000  25.000000

# %%
# (1) 挑「單一欄位」→ 用中括號 + 欄名
print("所有站名：")
print(df["站名"])

# (2) 挑「多個欄位」→ 中括號裡放一個清單
df[["站名", "可還"]]

# (3) 挑「符合條件的列」→ 在中括號裡放條件 (這叫布林篩選)
# 例如：找出「目前沒車可借」的站點
df[df["可還"] > 5]

# 用 & (且) 和 | (或) 串多個條件，每個條件要用小括號括起來
# 例如：大安區「而且」可借大於 10
df[(df["行政區"] == "松山區") & (df["可借"] > 2)]
# Out:
# 所有站名：
# 0     大安站
# 1     信義站
# 2     中山站
# 3     松山站
# 4    大安森林
# 5     市府站
# 6     南港站
# 7     內湖站
# Name: 站名, dtype: object
#     站名  行政區  可借  可還  總停車格   使用率
# 3  松山站  松山區   5  15    20  0.75

# %%
# (1) 排序：依「可借」數量由多到少
df.sort_values("可借", ascending=False)

# (2) 分組統計 groupby：每個行政區的可借車輛「總和」
# 意思是：先按行政區分堆，再把每堆的「可借」加起來
df.groupby("行政區")["可借"].sum()

# groupby 也可以算平均、數量等
print("各行政區的平均可借車輛：")
print(df.groupby("行政區")["可借"].mean())

print("\n各行政區有幾個站：")
print(df.groupby("行政區")["站名"].count())

# (3) 新增欄位：用現有欄位算出新的
# 例如算「使用率」= 可還 / 總停車格 (車位被停走的比例)
df["使用率"] = df["可還"] / df["總停車格"]
df[["站名", "可還", "總停車格", "使用率"]]
# Out:
# 各行政區的平均可借車輛：
# 行政區
# 中山區     8.0
# 信義區     1.5
# 內湖區    15.0
# 南港區     0.0
# 大安區    16.0
# 松山區     5.0
# Name: 可借, dtype: float64
#
# 各行政區有幾個站：
# 行政區
# 中山區    1
# 信義區    2
# 內湖區    1
# 南港區    1
# 大安區    2
# 松山區    1
# Name: 站名, dtype: int64
#      站名  可還  總停車格   使用率
# 0   大安站   8    20  0.40
# 1   信義站  20    20  1.00
# 2   中山站  12    20  0.60
# 3   松山站  15    20  0.75
# 4  大安森林   0    20  0.00
# 5   市府站  17    20  0.85
# 6   南港站  25    25  1.00
# 7   內湖站   5    20  0.25

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import os
import urllib.request

# 下載 Google 的思源黑體 (Noto Sans TC)，存到本機
font_url = "https://github.com/googlefonts/noto-cjk/raw/main/Sans/OTF/TraditionalChinese/NotoSansCJKtc-Regular.otf"
font_path = "/content/NotoSansCJKtc-Regular.otf"

if not os.path.exists(font_path):
    print("下載中文字型中…")
    urllib.request.urlretrieve(font_url, font_path)
    print("下載完成！")

# 把字型註冊給 matplotlib
fm.fontManager.addfont(font_path)
plt.rcParams["font.family"] = "Noto Sans CJK TC"
plt.rcParams["axes.unicode_minus"] = False   # 讓負號正常顯示
# Out:
# 下載中文字型中…
# 下載完成！

# %%
# (1) 長條圖 bar：各站可借車輛
plt.figure(figsize=(12, 4))
plt.bar(df["站名"], df["可借"])
plt.title("各站目前可借車輛")
plt.xlabel("站名")
plt.ylabel("可借數量")
plt.show()
